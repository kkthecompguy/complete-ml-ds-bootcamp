# %% [markdown]
# ![picture](https://cdn-images-1.medium.com/max/2400/1*Gf0bWgr2wst9A1XR5gakLg.png)

# %% [markdown]
# ## Major Steps
# 1. Create a framework
# 2. Match to data science and machine learning tools
# 3. Learn by doing.

# %% [markdown]
# ## 1. Problem definition
# "What problem are we trying to solve"
#
# * Supervised
# * Unsupervised
# * Classification
# * Regression
#
# ## 2. Data
# "what kind of data do we have"
# * Structured
# * Unstructured
#
# ## 3 Evaluation ✅
# "What defined a success for use"
# > Since we are practioners we know that a perfect model does not exist
#
# ## 4. Features
# "What do we already know about the data?"
#
# ## 5. Modelling
# "Based on our problem and data, what model should we use?"
#
# ## 6. Experimentation
# "How could we improve/what can we try next

# %% [markdown]
# > 🔑 **Note:** Machine Learning isn't a solution to every problem
# * Will a simple hand coded instruction based system work? yes --- Got for it

# %% [markdown]
# ## Main Types of Machine Learning Problems
# * Supervised Learning (data, label)
#   * classification
#     * "Is this example one thing or another"
#     * Binary classification = two options
#     * Multi-class classification = more than two options
#   * regression
#     * "Trying to predict a number" / *continuous number*
#     * How much will this house sell for?
#     * How many people will buy this app?
#
# * Unsupervised Learning (data, no label)
#   * clustering
#   * recommendation problem
# * Transfer Learning
#   * leverage what one machine learning model has learned in another machine learning problem
# * Reinforcement Learning
#   * involves having a computer program performs some actions within a defined space and rewards it for doing it well or purnish it for doing it poorly

# %% [markdown]
# ## Different Types of data
# * Structured (static)
# * Unstructured (streaming data change over time)
#
# > The more data the better

# %% [markdown]
# ## A data science workflow
# ```
# static data (csv) ---> Jupyter & Jupyter Notebooks ---> pandas DataFrame ---> visualize the data (Matplotlib) ---> Machine Learning Model (scikit-learn) ---> predict whether a person has heart disease or not
# ```
#
# > 🔑 **Note:** For this project to be worth pursing further, we need a machine learning model with over 99% accuracy 97.8%

# %% [markdown]
# ## Different types of metrics
#
# |Classification|Regression|Recommendation|
# |---|---|---|
# |Accuracy| Mean absoluate error (MAE)| Precision at K|
# |Precision|Mean squared error (MSE)| |
# |Recall| Root mean squared error| |

# %% [markdown]
# ## Different features of data
# * Feature variable
#   * numerical
#   * categorical
#   * derived
# * Target variable
#
# **Feature engineering** - looking at different features of data and creating new ones/altering existing ones
#
# **Feature coverage** - How many sample have different features? Ideally every sample has the same features

# %% [markdown]
# ## 3 parts to modelling
# 1. Choosing and training a model
# 2. Tuning a model
# 3. Model comparison
#
# > The most importance concept in machine learning (the training, validation and test sets or 3 sets)
#  * The training
#  * Validation
#  * Test sets
#
#  **Generalization** The ability for a machine learning to perform well on data it hasn't seen before.

# %% [markdown]
# ## Things to remember
# * Machine learning models have hyperparameters you can adjust
# * A model first results aren't its last
# * Tuning can take place on training or validation data sets

# %%
# !ls
# Out:
# drive  sample_data
